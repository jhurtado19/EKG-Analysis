# %% [markdown]
# <a href="https://colab.research.google.com/github/jhurtado19/EKG-Analysis/blob/main/jesse75.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 75 lbs EKG analysis

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from scipy.io import wavfile
import numpy as np
samplerate, data = wavfile.read('/content/gdrive/MyDrive/Group 6/Final Project Data/jesse_75.wav')
print(samplerate)
print(data)
# Out:
# 10000
# [6277 6298 6318 ... 6004 6052 6101]

# %%
import matplotlib.pyplot as plt
plt.plot(data)
plt.xlabel('Time x (10E-4)')
plt.ylabel('Voltage (10E-4 V)')
# Out:
# Text(0, 0.5, 'Voltage (10E-4 V)')

# %%
clip = data[1000 : 30000]
plt.plot(clip, scalex= True, scaley=True)

# %%
ekgclip = clip[7300 : 13100]
plt.plot(ekgclip)
ekgclip2 = clip[13700 : 20000]
plt.plot(ekgclip2)

# %%
ekgclip3 = clip[1190 : 10000]
plt.plot(ekgclip3)
ekgclip = clip[7690 : 16000]
plt.plot(ekgclip)
ekgclip2 = clip[14110 : 25000]
plt.plot(ekgclip2)
plt.

# %%
ekgclipn = data[30000 : 40000]
plt.plot(ekgclipn)

# %%
ekgclipn = data[40000 : 50000]
plt.plot(ekgclipn)

# %%
ekgclipn = data[50000 : 60000]
plt.plot(ekgclipn)

# %%
import matplotlib.pyplot as plt
def averageGreater(array, lim):
  plt.plot(array)
  sum = 0
  length = 0
  i = 1
  print(f"Peak values greater than {lim}")
  while i < len(array) - 1:
    if array[i] > lim and array[i] >= array[i-1] and array[i] >= array[i+1]:
      print(array[i])
      plt.vlines(i,8000,-4000)
      sum += array[i]
      length += 1
      while array[i] == array[i+1]:
        i += 1
    i += 1
  print(f"Average: {sum / length}")

# %%
averageGreater(data[30000 : 40000],7662)
# Out:
# Peak values greater than 7662
# 10510
# 8968
# 7815
# 9249
# 12840
# 12041
# 10206
# Average: 10232.714285714286

# %%
averageGreater(data[37000 : 50000],7662)
# Out:
# Peak values greater than 7662
# 7815
# 9249
# 12840
# 12041
# 10206
# 11820
# 10115
# 11213
# 7884
# 11581
# 7733
# 9028
# Average: 10127.083333333334

# %%
averageGreater(data[50000 : 60000],7662)
# Out:
# Peak values greater than 7662
# 11884
# 11885
# 11837
# 9934
# 9441
# 9442
# 9214
# 11920
# 10942
# 7942
# 8719
# 8718
# 8296
# 7878
# Average: 9860.857142857143

# %%
averageGreater(data[60000 : 70000],7662)
# Out:
# Peak values greater than 7662
# 9402
# 8802
# 10945
# 7798
# 7797
# 8929
# 7820
# Average: 8784.714285714286

# %%
averageGreater(data[0 : 30000],5000)
# Out:
# Peak values greater than 5000
# 6816
# 6817
# 6818
# 5833
# 8982
# 8983
# 5761
# 5733
# 6179
# 5723
# 6012
# 5670
# 5668
# 5668
# 5667
# 5668
# 5669
# 5673
# 5685
# 5686
# 5686
# 8528
# 8040
# 8039
# 9125
# 7339
# 7338
# 5540
# 5539
# 5541
# 6040
# 8848
# 7784
# 5644
# 5755
# 5756
# 5755
# 9046
# Average: 6580.368421052632
