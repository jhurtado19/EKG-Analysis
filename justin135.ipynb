# %% [markdown]
# <a href="https://colab.research.google.com/github/jhurtado19/EKG-Analysis/blob/main/justin135.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 135 lbs EKG analysis

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from scipy.io import wavfile
import numpy as np
samplerate, data = wavfile.read('/content/gdrive/MyDrive/Group 6/Final Project Data/justin_135.wav')
print(samplerate)
print(data)
# Out:
# 10000
# [8799 8939 9076 ...  964 1043 1124]

# %%
import matplotlib.pyplot as plt
plt.plot(data[0 : 40000])
plt.xlabel('Time x (10E-4)')
plt.ylabel('Voltage (10E-4 V)')
# Out:
# Text(0, 0.5, 'Voltage (10E-4 V)')

# %%
import matplotlib.pyplot as plt
def averageGreater(array, lim):
  plt.plot(array)
  sum = 0
  length = 0
  i = 1
  print(f"Peak values greater than {lim}")
  while i < len(array) - 1:
    if array[i] > lim and array[i] >= array[i-1] and array[i] >= array[i+1]:
      print(array[i])
      plt.vlines(i,8000,-4000)
      sum += array[i]
      length += 1
      while array[i] == array[i+1]:
        i += 1
    i += 1
  print(f"Average: {sum / length}")

# %%
averageGreater(data[0 : 10000],5000)
# Out:
# Peak values greater than 5000
# 11582
# 10013
# 10805
# 10806
# 10804
# 11276
# 11277
# 11485
# 6569
# 11071
# 11233
# 12901
# 12462
# 14864
# 13716
# 13461
# 12233
# 12234
# 12233
# 12287
# 12286
# 12383
# 11443
# 5791
# Average: 11467.291666666666

# %%
averageGreater(data[10000 : 20000],5000)
# Out:
# Peak values greater than 5000
# 8217
# 13103
# 10782
# 11679
# 9962
# 6556
# 11937
# 5978
# 6771
# 7509
# 9668
# 7836
# 11311
# 11268
# 12582
# 5172
# 12160
# 7240
# 5984
# 9331
# 6413
# 11572
# 7112
# Average: 9136.652173913044

# %%
averageGreater(data[20000 : 30000],5000)
# Out:
# Peak values greater than 5000
# 8097
# 12208
# 12162
# 7794
# 8920
# 8523
# 9264
# 6239
# 6240
# 6239
# 10375
# 8009
# 6834
# 9370
# 10031
# 10429
# 8204
# 8281
# 10159
# Average: 8809.368421052632
